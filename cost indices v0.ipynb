# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print ("new")
# Out:
# new

# %% [markdown]
# This code will try to assess the differences between several alternatives for the CII cost normalixatin index. More specifically, the focus will be on international rates although domestic rates for the U.S. may also be addressed.

# %% [markdown]
# Add HIS indices to the list: https://www.ihs.com/info/cera/ihsindexes/index.html
#
#
# From: Oliveira, Daniel P
# Sent: Monday, October 9, 2017 11:09 AM
# To: Hyeon Yong Park <hyeon.park@cii.utexas.edu>
# Subject: quick search on cost indices
#
# I just spent some time on google and here is what I found:
#
# European construction indices: http://constructioncosts.eu/cost-index/
# They mention that they have a data by sector by I did not figure out what those data are.
#
# Arcadis seems to provide an annual report on construction costs:
# https://www.arcadis.com/en/global/our-perspectives/international-construction-costs-2017/
# https://www.arcadis.com/media/3/6/8/%7B368131AD-E31B-4552-821B-1F66DC62F805%7DICC%202017_FINAL_singles.pdf
# https://www.arcadis.com/media/6/0/A/%7B60AADA64-E765-4AF8-900B-A89DC6EF47CB%7DFIG%201_International%20Cost%20Comparison%20chart_300dpi%20CMYK.jpg
#
# OECD has price indices: https://data.oecd.org/price/price-level-indices.htm
# It would be good to see how these compare to construction indices
#
#
# IMF Commodities prices (I am interested in these for the JIP project) http://www.imf.org/external/np/res/commod/index.aspx
# http://www.imf.org/external/np/res/commod/pdf/monthly/060917.pdf
#
# RLB
# http://assets.rlb.com/production/2016/11/28065747/RLB-Global-Construction-Market-Intelligence-Report-October-20161.pdf
#
# Here is an A&M page with several indices (it seems they have in their library and we may have that as well)
# http://tamu.libguides.com/c.php?g=587308&p=4155565 (it seems we have the Oil; and gas Journal: http://catalog.lib.utexas.edu/record=b2995005)
#
#
# Purchaseing Power parity
# https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD?end=2016&start=1990&view=chart&year_high_desc=true
#
# Jason’s paper is also a good reference to understand options: http://ascelibrary.org/doi/pdf/10.1061/9780784412329.241

# %%
#Read excel file
raw_file=pd.ExcelFile('datasets/Copy of Indices - October 2017.xlsx')
hc=raw_file.parse('Hanscomb')
hc
# Out:
#             country        city index_year  cost_index
# 0         Australia   Melbourne 1905-07-08       86.80
# 1         Australia   Melbourne 2011-04-01      110.30
# 2         Australia   Melbourne 2011-10-01      110.30
# 3         Australia   Melbourne 2012-04-01      114.40
# 4         Australia   Melbourne 2012-10-01      114.40
# 5         Australia   Melbourne 2013-04-01      110.90
# 6         Australia   Melbourne 2013-10-01      110.90
# 7         Australia   Melbourne 2014-04-01      115.90
# 8         Australia   Melbourne 2014-10-01      115.90
# 9         Australia   Melbourne 2015-04-01      115.90
# 10        Australia   Melbourne 2015-10-01      115.90
# 11        Australia   Melbourne 2016-04-01       86.80
# 12        Australia   Melbourne 2016-10-19       86.80
# 13        Australia      Sydney 1905-07-08         NaN
# 14        Australia      Sydney 2000-04-01       85.90
# 15        Australia      Sydney 2000-10-01       78.22
# ...

# %%
hc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 4 columns):
# country       1113 non-null object
# city          1113 non-null object
# index_year    1113 non-null datetime64[ns]
# cost_index    1069 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 34.9+ KB

# %%
hc_us=hc[hc['country']=='United States']
hc_us=hc_us[hc_us['index_year'] > '2000-01-01']
hc_us=hc_us[hc_us['city'] == 'Chicago']

#hc_us_byyear=hc_us.groupby('')
hc_us=hc_us.sort_values('index_year',ascending=True)
plt.plot(hc_us['index_year'],hc_us['cost_index'])
plt.xticks(rotation='vertical')
hc_us
#https://stackoverflow.com/questions/41815126/plot-datetime-date-pandas
# Out:
#             country     city index_year  cost_index
# 1076  United States  Chicago 2000-04-01       100.0
# 1077  United States  Chicago 2000-10-01       100.0
# 1078  United States  Chicago 2001-04-01       100.0
# 1079  United States  Chicago 2001-10-01       100.0
# 1080  United States  Chicago 2002-04-01       100.0
# 1081  United States  Chicago 2002-10-01       100.0
# 1082  United States  Chicago 2003-04-01       100.0
# 1083  United States  Chicago 2003-10-01       100.0
# 1084  United States  Chicago 2004-04-01       100.0
# 1085  United States  Chicago 2004-10-01       100.0
# 1086  United States  Chicago 2005-04-01       100.0
# 1087  United States  Chicago 2005-10-01       100.0
# 1088  United States  Chicago 2006-04-01       100.0
# 1089  United States  Chicago 2006-10-01       100.0
# 1090  United States  Chicago 2007-04-01       100.0
# 1091  United States  Chicago 2007-10-01       100.0
# 1092  United States  Chicago 2008-04-01       100.0
# ...

# %%
hc_us['year']=hc_us['index_year'].apply(lambda x: x.year )
hc_us
# Out:
#             country     city index_year  cost_index  year
# 1076  United States  Chicago 2000-04-01       100.0  2000
# 1077  United States  Chicago 2000-10-01       100.0  2000
# 1078  United States  Chicago 2001-04-01       100.0  2001
# 1079  United States  Chicago 2001-10-01       100.0  2001
# 1080  United States  Chicago 2002-04-01       100.0  2002
# 1081  United States  Chicago 2002-10-01       100.0  2002
# 1082  United States  Chicago 2003-04-01       100.0  2003
# 1083  United States  Chicago 2003-10-01       100.0  2003
# 1084  United States  Chicago 2004-04-01       100.0  2004
# 1085  United States  Chicago 2004-10-01       100.0  2004
# 1086  United States  Chicago 2005-04-01       100.0  2005
# 1087  United States  Chicago 2005-10-01       100.0  2005
# 1088  United States  Chicago 2006-04-01       100.0  2006
# 1089  United States  Chicago 2006-10-01       100.0  2006
# 1090  United States  Chicago 2007-04-01       100.0  2007
# ...

# %%
#reading from an online source
#reading what?
from pandas import read_html
url='https://www.bls.gov/regions/mid-atlantic/data/consumerpriceindexhistorical_us_table.htm'
url='https://data.oecd.org/price/producer-price-indices-ppi.htm'
df=pd.io.html.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-beed461bb0bd> in <module>()
#       4 url='https://www.bls.gov/regions/mid-atlantic/data/consumerpriceindexhistorical_us_table.htm'
#       5 url='https://data.oecd.org/price/producer-price-indices-ppi.htm'
# ----> 6 df=pd.io.html.read_html(url)
#
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     904                   thousands=thousands, attrs=attrs, encoding=encoding,
#     905                   decimal=decimal, converters=converters, na_values=na_values,
# --> 906                   keep_default_na=keep_default_na)
#
# ...

# %%
df[0]
# Out:
#           ALL ITEMS\n(1982-84=100)\n  U.S. City Average Unnamed: 2_level_0  \
#                                   Jan               Feb                Mar
# 0                Consumer Price Index               NaN                NaN
# 1                                2007           202.416            203.499
# 2                                2008           211.080            211.693
# 3                                2009           211.143            212.193
# 4                                2010           216.687            216.741
# 5                                2011           220.223            221.309
# 6                                2012           226.665            227.663
# 7                                2013           230.280            232.166
# 8                                2014           233.916            234.781
# 9                                2015           233.707            234.722
# ...

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
